# %%
import pandas as pd

# %%
data= pd.read_csv(r'D:\netflix_titles.csv')

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
  data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.size
# Out:
# 105684

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Checking for duplicates and droping them

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_n, year]
# Index: []

# %% [markdown]
# # Checking for null values and ploting a heat-map

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
 data[data['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
 data[data['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # In which year highest content were released

# %%
 data['Date_n']= pd.to_datetime(data['date_added'])

# %%
data['release_year'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_n          datetime64[ns]
# dtype: object

# %%
data['Date_n'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Date_n'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_n, dtype: int64

# %% [markdown]
# # how many movies and TV shows in data set showing it with bar graph

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_n
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_n
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data['year'] = data['Date_n'].dt.year

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_n    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['type']=='Movie') &(data['year']==2016)]
# Out:
#      show_id   type                                              title  \
# 5652   s5653  Movie                                            Mr. Pig
# 5656   s5657  Movie                                               7:19
# 5657   s5658  Movie          Garfunkel and Oates: Trying to be Special
# 5659   s5660  Movie  A Christmas Special: Miraculous: Tales of Lady...
# 5660   s5661  Movie  Gabriel lglesias: I’m Sorry For What I Said Wh...
# ...      ...    ...                                                ...
# 8781   s8782  Movie                            Yo-Kai Watch: The Movie
# 8782   s8783  Movie                                        Yoga Hosers
# 8788   s8789  Movie                                       You Carry Me
# 8792   s8793  Movie                                        Young Tiger
# 8801   s8802  Movie                                            Zinzana
#
#                           director  \
# 5652                    Diego Luna
# 5656             Jorge Michel Grau
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_n    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[ (data['type']=='TV Show') & (data['country']== 'United States')]
# Out:
#      show_id     type                                   title director  \
# 15       s16  TV Show                       Dear White People      NaN
# 40       s41  TV Show  He-Man and the Masters of the Universe      NaN
# 55       s56  TV Show                               Nailed It      NaN
# 67       s68  TV Show                       Saved by the Bell      NaN
# 82       s83  TV Show                                 Lucifer      NaN
# ...      ...      ...                                     ...      ...
# 8710   s8711  TV Show                                   Weeds      NaN
# 8726   s8727  TV Show                    When Calls the Heart      NaN
# 8747   s8748  TV Show                               Winsanity      NaN
# 8755   s8756  TV Show                       Women Behind Bars      NaN
# 8780   s8781  TV Show                            Yo-Kai Watch      NaN
#
#                                                    cast        country  \
# ...

# %%
data[ (data['type']=='TV Show') & (data['country']== 'United States')] ['title']
# Out:
# 15                           Dear White People
# 40      He-Man and the Masters of the Universe
# 55                                   Nailed It
# 67                           Saved by the Bell
# 82                                     Lucifer
#                          ...
# 8710                                     Weeds
# 8726                      When Calls the Heart
# 8747                                 Winsanity
# 8755                         Women Behind Bars
# 8780                              Yo-Kai Watch
# Name: title, Length: 760, dtype: object

# %% [markdown]
# # Top 10 Directors , who gave highest content

# %%
data.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
data['director'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # type is movie,genre is dramas and country is USA

# %%
data.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Dramas')&(data['country']== 'United States') ]
# Out:
#      show_id   type                title                director  \
# 343     s344  Movie              My Girl            Howard Zieff
# 446     s447  Movie    The Book of Henry         Colin Trevorrow
# 599     s600  Movie  The Best of Enemies           Robin Bissell
# 630     s631  Movie  Killing Them Softly          Andrew Dominik
# 685     s686  Movie           Fatherhood              Paul Weitz
# ...      ...    ...                  ...                     ...
# 8505   s8506  Movie             The Show      Giancarlo Esposito
# 8511   s8512  Movie   The Social Network           David Fincher
# 8636   s8637  Movie     True to the Game  Preston A. Whitmore II
# 8675   s8676  Movie               Victor       Brandon Dickerson
# 8691   s8692  Movie            Wakefield           Robin Swicord
#
#                                                    cast        country  \
# 343   Dan Aykroyd, Jamie Lee Curtis, Macaulay Culkin...  United States
# ...

# %% [markdown]
# # in how many movies Kevin Hart was cast

# %%
data.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
data[data['cast']=='Kevin Hart']
# Out:
#      show_id   type                               title  \
# 1686   s1687  Movie        Kevin Hart: Zero F**ks Given
# 2978   s2979  Movie  Kevin Hart: I'm a Grown Little Man
# 3952   s3953  Movie           Kevin Hart: Irresponsible
# 7178   s7179  Movie        Kevin Hart: Laugh at My Pain
# 7179   s7180  Movie          Kevin Hart: Let Me Explain
# 7180   s7181  Movie         Kevin Hart: Seriously Funny
#
#                      director        cast        country         date_added  \
# 1686             Leslie Small  Kevin Hart  United States  November 17, 2020
# 2978          Shannon Hartman  Kevin Hart  United States   January 30, 2020
# 3952             Leslie Small  Kevin Hart  United States      April 2, 2019
# 7178  Leslie Small, Tim Story  Kevin Hart  United States    October 1, 2018
# 7179  Leslie Small, Tim Story  Kevin Hart  United States      July 13, 2018
# 7180          Shannon Hartman  Kevin Hart  United States    October 1, 2018
#
# ...

# %% [markdown]
# # in how many movies Tom Cruise was cast

# %%
data[data['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_n, year]
# Index: []

# %%
data[data['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 data[data['cast'].str.contains('Tom Cruise')]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
#     140     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     141     if lib.infer_dtype(key) == "boolean" and isna(key).any():
# ...

# %% [markdown]
# so we have to drop null values

# %%
data_new =  data.dropna()

# %%
data_new.head()

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]

# %% [markdown]
# # Different ratings by netflix

# %%
data.head(3)

# %%
data['rating'].nunique()

# %%
data['rating'].unique()

# %% [markdown]
# #    How many movies get the PG rating in USA

# %%
data[(data['type']=='Movie') & (data['rating']=='PG')].head()

# %%
data[(data['type']=='Movie') & (data['rating']=='PG')].shape

# %%
data[(data['type']=='Movie') & (data['rating']=='PG')& (data['country']=='United States')] .head()

# %%
data[(data['type']=='Movie') & (data['rating']=='PG')& (data['country']=='United States')] .shape

# %% [markdown]
# # How many tv shows got TV-G rating

# %%
data.head(3)

# %%
data[(data['type']=='TV Show') & (data['rating']=='TV-G')]

# %% [markdown]
# # Max duration of a content

# %%
data.head(3)

# %%
data.duration.unique()

# %%
data.duration.dtypes

# %%
data[['minutes','unit']]= data['duration'].str.split(' ', expand=True)

# %%
data.head(3)

# %%
data.minutes

# %% [markdown]
# # which country has highest shows

# %%
data.head(3)

# %%
data_tv = data[data['type']=='TV Show']

# %%
data_tv.head(3)

# %%
data_tv.country.value_counts().head()

# %% [markdown]
# # Sorting Data by Year

# %%
data.sort_values(by = 'year')

# %% [markdown]
# Analysis by Waleed Hassan
